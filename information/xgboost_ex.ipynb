# %% [markdown]
# ### This jupyter notebook contains the information about xgboost algorithms from various websites

# %% [markdown]
# educative.i0 information

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
